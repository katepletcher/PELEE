# %%
import uproot

# %% [markdown]
# BNB MCC9.10 Samples

# %%
# # Beam On
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_on_surprise_reco2_hist_4c.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4c-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

# %%
# # Beam On
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4d_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_on_surprise_reco2_hist_4d.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4d-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

# %%
# # Beam On
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run5_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_on_surprise_reco2_hist_5.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run5-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_4c.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4c-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4d_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_4d.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4d-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run5_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_5.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run5-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Open Data
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/opendata/BNB/checkout_MCC9.10_Run4a_BNB_beam_on_data_surprise_reco2_hist_opendata_19550.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4a-run-subrun-list-openData.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4a_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4a_BNB_beam_off_data_surprise_reco2_hist.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4a-BNB-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Open Data
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/opendata/BNB/checkout_MCC9.10_Run4a_BNB_beam_on_data_surprise_reco2_hist_opendata_19550.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4a-BNB-run-subrun-list-openData.txt",header=None, index=None, sep=' ')

# %%
# # Beam On
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4a_full_samples/wc_processed/BNB/checkout_MCC9.10_Run4a_BNB_beam_on_data_surprise_reco2_hist.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4a-BNB-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

# %% [markdown]
# NuMI MCC9.10 EXT Samples

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4a_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_off_surprise_reco2_hist_4a.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4a-RHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/retuple/NuMI/checkout_MCC9.10_Run4b_v10_04_07_20_NuMI_beam_off_retuple_retuple_hist.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4b-RHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_off_surprise_reco2_hist_4c_RHC.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4c-RHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_off_surprise_reco2_hist_4c_FHC.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run4c-FHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4d_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_off_surprise_reco2_hist_4d.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4d-FHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# # Beam Off
# data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run5_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_off_surprise_reco2_hist_5.root"
# tree = uproot.open(data_file)["nuselection"]["SubRun"]
# df   = tree.arrays(["run", "subRun"], library="pd")
# df.to_csv("run5-FHC-numi-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')

# %%
# Beam On
data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4a_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_on_surprise_reco2_hist_4a.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4a-RHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4b_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4b_NuMI_beam_on_RHC_data_surprise_v10_04_07_09_reco2_hist.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4b-RHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_on_surprise_reco2_hist_4c_RHC.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4c-RHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4c_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_on_surprise_reco2_hist_4c_FHC.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4c-FHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run4d_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_on_surprise_reco2_hist_4d.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run4d-FHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')

data_file = "/pnfs/uboone/persistent/users/uboonepro/surprise/run5_full_samples/wc_processed/NuMI/checkout_MCC9.10_Run4acd5_v10_04_07_14_NuMI_beam_on_surprise_reco2_hist_5.root"
tree = uproot.open(data_file)["nuselection"]["SubRun"]
df   = tree.arrays(["run", "subRun"], library="pd")
df.to_csv("run5-FHC-numi-run-subrun-list-beamOn.txt",header=None, index=None, sep=' ')
