# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import uproot as up
import pickle
import nue_booster
import importlib
importlib.reload(nue_booster)

import awkward

# %%
# SURPRISE SAMPLES
u_nu4a = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4a.root")["nuselection"]["SubRun"]
u_nu4a_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4a.root")["nuselection"]["NeutrinoSelectionFilter"]
u_nue4a = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_4a.root")["nuselection"]["SubRun"]
u_nue4a_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_4a.root")["nuselection"]["NeutrinoSelectionFilter"]
u_dirt4a = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_dirt_overlay_surprise_reco2_hist_4a.root")["nuselection"]["SubRun"]
u_ncpi04a = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4a_v10_04_07_16_BNB_NCpi0_overlay_surprise_reco2_hist.root")["nuselection"]["SubRun"]
u_ext4a = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4a/nuepresel/checkout_MCC9.10_Run4a_BNB_beam_off_data_surprise_reco2_hist.root")["nuselection"]["SubRun"]

u_nu4b = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist.root")["nuselection"]["SubRun"]
u_nu4b_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist.root")["nuselection"]["NeutrinoSelectionFilter"]
u_nue4b = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_09_BNB_nue_overlay_surprise_reco2_hist.root")["nuselection"]["SubRun"]
u_nue4b_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_09_BNB_nue_overlay_surprise_reco2_hist.root")["nuselection"]["NeutrinoSelectionFilter"]
u_dirt4b = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_09_BNB_dirt_surpise_reco2_hist.root")["nuselection"]["SubRun"]
u_ncpi04b = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_09_BNB_NC_pi0_overlay_surprise_reco2_hist.root")["nuselection"]["SubRun"]
u_ext4b = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4b/nuepresel/checkout_MCC9.10_Run4b_v10_04_07_20_BNB_beam_off_metapatch_retuple_retuple_hist.root")["nuselection"]["SubRun"]

u_nu4c = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4c.root")["nuselection"]["SubRun"]
u_nu4c_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4c.root")["nuselection"]["NeutrinoSelectionFilter"]
u_nue4c = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4c_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_redo_reco2_hist.root")["nuselection"]["SubRun"]
u_nue4c_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4c_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_redo_reco2_hist.root")["nuselection"]["NeutrinoSelectionFilter"]
u_dirt4c = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_dirt_overlay_surprise_reco2_hist_4c.root")["nuselection"]["SubRun"]
u_ncpi04c = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4c4d5_v10_04_07_13_BNB_NCpi0_overlay_surprise_reco2_hist_4c.root")["nuselection"]["SubRun"]
u_ext4c = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4c/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_4c.root")["nuselection"]["SubRun"]

u_nu4d = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4d.root")["nuselection"]["SubRun"]
u_nu4d_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_4d.root")["nuselection"]["NeutrinoSelectionFilter"]
u_nue4d = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_4d.root")["nuselection"]["SubRun"]
u_nue4d_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_4d.root")["nuselection"]["NeutrinoSelectionFilter"]
u_dirt4d = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_dirt_overlay_surprise_reco2_hist_4d.root")["nuselection"]["SubRun"]
u_ncpi04d = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4c4d5_v10_04_07_13_BNB_NCpi0_overlay_surprise_reco2_hist_4d.root")["nuselection"]["SubRun"]
u_ext4d = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run4d/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_4d.root")["nuselection"]["SubRun"]

u_nu5 = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_5.root")["nuselection"]["SubRun"]
u_nu5_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_20_BNB_nu_overlay_retuple_retuple_hist_5.root")["nuselection"]["NeutrinoSelectionFilter"]
u_nue5 = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_5.root")["nuselection"]["SubRun"]
u_nue5_nufilter = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_intrinsic_nue_overlay_surprise_reco2_hist_5.root")["nuselection"]["NeutrinoSelectionFilter"]
u_dirt5 = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4a4c4d5_v10_04_07_13_BNB_dirt_overlay_surprise_reco2_hist_5.root")["nuselection"]["SubRun"]
u_ncpi05 = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4c4d5_v10_04_07_13_BNB_NCpi0_overlay_surprise_reco2_hist_5.root")["nuselection"]["SubRun"]
u_ext5 = up.open("/exp/uboone/data/users/kpletcher/slimmedFiles/slimmedMCC910/run5/nuepresel/checkout_MCC9.10_Run4acd5_v10_04_07_14_BNB_beam_off_surprise_reco2_hist_5.root")["nuselection"]["SubRun"]

# %%
# pd.set_option('display.max_rows', None)

vars = ["pot", "run", "subRun"]
vars_query = ["run", "sub", "nu_pdg", "ccnc", "mcf_pass_ncpi0", "category"]

# Run 4a
nu4a_subRun = u_nu4a.arrays(vars, library='pd')
nu4a_nueSelFilter = u_nu4a_nufilter.arrays(vars_query, library='pd')
nu4a_duplicates = pd.merge(nu4a_subRun, nu4a_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nu4a = nu4a_duplicates.drop_duplicates(subset=['subRun','pot'])

nue4a_subRun = u_nue4a.arrays(vars, library='pd')
nue4a_nueSelFilter = u_nue4a_nufilter.arrays(vars_query, library='pd')
nue4a_duplicates = pd.merge(nue4a_subRun, nue4a_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nue4a = nue4a_duplicates.drop_duplicates(subset=['subRun','pot'])

dirt4a = u_dirt4a.arrays(vars, library='pd')
ncpi04a = u_ncpi04a.arrays(vars, library='pd')

# Run 4b
nu4b_subRun = u_nu4b.arrays(vars, library='pd')
nu4b_nueSelFilter = u_nu4b_nufilter.arrays(vars_query, library='pd')
nu4b_duplicates = pd.merge(nu4b_subRun, nu4b_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nu4b = nu4b_duplicates.drop_duplicates(subset=['subRun','pot'])

nue4b_subRun = u_nue4b.arrays(vars, library='pd')
nue4b_nueSelFilter = u_nue4b_nufilter.arrays(vars_query, library='pd')
nue4b_duplicates = pd.merge(nue4b_subRun, nue4b_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nue4b = nue4b_duplicates.drop_duplicates(subset=['subRun','pot'])

dirt4b = u_dirt4b.arrays(vars, library='pd')
ncpi04b = u_ncpi04b.arrays(vars, library='pd')

# Run 4c
nu4c_subRun = u_nu4c.arrays(vars, library='pd')
nu4c_nueSelFilter = u_nu4c_nufilter.arrays(vars_query, library='pd')
nu4c_duplicates = pd.merge(nu4c_subRun, nu4c_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nu4c = nu4c_duplicates.drop_duplicates(subset=['subRun','pot'])

nue4c_subRun = u_nue4c.arrays(vars, library='pd')
nue4c_nueSelFilter = u_nue4c_nufilter.arrays(vars_query, library='pd')
nue4c_duplicates = pd.merge(nue4c_subRun, nue4c_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nue4c = nue4c_duplicates.drop_duplicates(subset=['subRun','pot'])

dirt4c = u_dirt4c.arrays(vars, library='pd')
ncpi04c = u_ncpi04c.arrays(vars, library='pd')

# Run 4d
nu4d_subRun = u_nu4d.arrays(vars, library='pd')
nu4d_nueSelFilter = u_nu4d_nufilter.arrays(vars_query, library='pd')
nu4d_duplicates = pd.merge(nu4d_subRun, nu4d_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nu4d = nu4d_duplicates.drop_duplicates(subset=['subRun','pot'])

nue4d_subRun = u_nue4d.arrays(vars, library='pd')
nue4d_nueSelFilter = u_nue4d_nufilter.arrays(vars_query, library='pd')
nue4d_duplicates = pd.merge(nue4d_subRun, nue4d_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nue4d = nue4d_duplicates.drop_duplicates(subset=['subRun','pot'])

dirt4d = u_dirt4d.arrays(vars, library='pd')
ncpi04d = u_ncpi04d.arrays(vars, library='pd')

# Run 5
nu5_subRun = u_nu5.arrays(vars, library='pd')
nu5_nueSelFilter = u_nu5_nufilter.arrays(vars_query, library='pd')
nu5_duplicates = pd.merge(nu5_subRun, nu5_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nu5 = nu5_duplicates.drop_duplicates(subset=['subRun','pot'])

nue5_subRun = u_nue5.arrays(vars, library='pd')
nue5_nueSelFilter = u_nue5_nufilter.arrays(vars_query, library='pd')
nue5_duplicates = pd.merge(nue5_subRun, nue5_nueSelFilter, left_on=["run","subRun"], right_on=["run","sub"], how="left")
nue5 = nue5_duplicates.drop_duplicates(subset=['subRun','pot'])

dirt5 = u_dirt5.arrays(vars, library='pd')
ncpi05 = u_ncpi05.arrays(vars, library='pd')

# %%
nue_signal = 'ZP'
# nue_signal = 'ZP_NP'

NUEQUERY = '(abs(nu_pdg)==12 & ccnc==0)'
NCPI0QUERY = '(mcf_pass_ncpi0==1)'
MCQUERY = '((abs(nu_pdg)==12 & ccnc==0) | mcf_pass_ncpi0==1)'

ZPQUERY = 'category==10'
NPQUERY = 'category==11'
NUEOTHERQUERY = '(category!=10 & category!=11)'

# Run 4a
# Query nu overlay sample
nu4a_ccnue = nu4a.query(NUEQUERY)
nu4a_ncpi0 = nu4a.query(NCPI0QUERY)
nu4a_no_ccnue_ncpi0 = nu4a.query('~'+MCQUERY)

# Split remaining nu overlay events
train_nu4a, test_nu4a = train_test_split(nu4a_no_ccnue_ncpi0, test_size=0.5, random_state=1990)

# Query nue overlay sample
nue4a_zp = nue4a.query(ZPQUERY)
nue4a_np = nue4a.query(NPQUERY)
nue4a_other = nue4a.query(NUEOTHERQUERY)

if nue_signal == 'ZP':
    # Make signal and background nue samples
    signal_nue4a = nue4a_zp
    bkg_nue4a = pd.concat([nue4a_np, nue4a_other], ignore_index=True)

if nue_signal == 'ZP_NP':
    # Make signal and background nue samples
    signal_nue4a = pd.concat([nue4a_zp, nue4a_np], ignore_index=True)
    bkg_nue4a = nue4a_other

# Split nue signal and background samples into training and testing samples
train_signal_nue4a, test_signal_nue4a = train_test_split(signal_nue4a, test_size=0.5)
train_bkg_nue4a, test_bkg_nue4a = train_test_split(bkg_nue4a, test_size=0.5)

# Re-unify the signal and background samples
test_nue4a = pd.concat([test_signal_nue4a, test_bkg_nue4a], ignore_index=True)
train_nue4a_truth = pd.concat([train_signal_nue4a, train_bkg_nue4a], ignore_index=True)
# Add nu overlay CC nue events to nue overlay training sample
train_nue4a = pd.concat([train_nue4a_truth, nu4a_ccnue], ignore_index=True)

# Split dirt and NC pi0 as normal
train_dirt4a, test_dirt4a = train_test_split(dirt4a, test_size=0.5, random_state=1990)
train_ncpi04a_truth, test_ncpi04a = train_test_split(ncpi04a, test_size=0.5, random_state=1990)
# Add nu overlay NC pi0 events to NC pi0 training sample
train_ncpi04a = pd.concat([train_ncpi04a_truth, nu4a_ncpi0], ignore_index=True)

# Run 4b
# Query nu overlay sample
nu4b_ccnue = nu4b.query(NUEQUERY)
nu4b_ncpi0 = nu4b.query(NCPI0QUERY)
nu4b_no_ccnue_ncpi0 = nu4b.query('~'+MCQUERY)

# Split remaining nu overlay events
train_nu4b, test_nu4b = train_test_split(nu4b_no_ccnue_ncpi0, test_size=0.5, random_state=1990)

# Query nue overlay sample
nue4b_zp = nue4b.query(ZPQUERY)
nue4b_np = nue4b.query(NPQUERY)
nue4b_other = nue4b.query(NUEOTHERQUERY)

if nue_signal == 'ZP':
    # Make signal and background nue samples
    signal_nue4b = nue4b_zp
    bkg_nue4b = pd.concat([nue4b_np, nue4b_other], ignore_index=True)

if nue_signal == 'ZP_NP':
    # Make signal and background nue samples
    signal_nue4b = pd.concat([nue4b_zp, nue4b_np], ignore_index=True)
    bkg_nue4b = nue4b_other

# Split nue signal and background samples into training and testing samples
train_signal_nue4b, test_signal_nue4b = train_test_split(signal_nue4b, test_size=0.5)
train_bkg_nue4b, test_bkg_nue4b = train_test_split(bkg_nue4b, test_size=0.5)

# Re-unify the signal and background samples
test_nue4b = pd.concat([test_signal_nue4b, test_bkg_nue4b], ignore_index=True)
train_nue4b_truth = pd.concat([train_signal_nue4b, train_bkg_nue4b], ignore_index=True)
# Add nu overlay CC nue events to nue overlay training sample
train_nue4b = pd.concat([train_nue4b_truth, nu4b_ccnue], ignore_index=True)

# Split dirt and NC pi0 as normal
train_dirt4b, test_dirt4b = train_test_split(dirt4b, test_size=0.5, random_state=1990)
train_ncpi04b_truth, test_ncpi04b = train_test_split(ncpi04b, test_size=0.5, random_state=1990)
# Add nu overlay NC pi0 events to NC pi0 training sample
train_ncpi04b = pd.concat([train_ncpi04b_truth, nu4b_ncpi0], ignore_index=True)

# Run 4c
# Query nu overlay sample
nu4c_ccnue = nu4c.query(NUEQUERY)
nu4c_ncpi0 = nu4c.query(NCPI0QUERY)
nu4c_no_ccnue_ncpi0 = nu4c.query('~'+MCQUERY)

# Split remaining nu overlay events
train_nu4c, test_nu4c = train_test_split(nu4c_no_ccnue_ncpi0, test_size=0.5, random_state=1990)

# Query nue overlay sample
nue4c_zp = nue4c.query(ZPQUERY)
nue4c_np = nue4c.query(NPQUERY)
nue4c_other = nue4c.query(NUEOTHERQUERY)

if nue_signal == 'ZP':
    # Make signal and background nue samples
    signal_nue4c = nue4c_zp
    bkg_nue4c = pd.concat([nue4c_np, nue4c_other], ignore_index=True)

if nue_signal == 'ZP_NP':
    # Make signal and background nue samples
    signal_nue4c = pd.concat([nue4c_zp, nue4c_np], ignore_index=True)
    bkg_nue4c = nue4c_other

# Split nue signal and background samples into training and testing samples
train_signal_nue4c, test_signal_nue4c = train_test_split(signal_nue4c, test_size=0.5)
train_bkg_nue4c, test_bkg_nue4c = train_test_split(bkg_nue4c, test_size=0.5)

# Re-unify the signal and background samples
test_nue4c = pd.concat([test_signal_nue4c, test_bkg_nue4c], ignore_index=True)
train_nue4c_truth = pd.concat([train_signal_nue4c, train_bkg_nue4c], ignore_index=True)
# Add nu overlay CC nue events to nue overlay training sample
train_nue4c = pd.concat([train_nue4c_truth, nu4c_ccnue], ignore_index=True)

# Split dirt and NC pi0 as normal
train_dirt4c, test_dirt4c = train_test_split(dirt4c, test_size=0.5, random_state=1990)
train_ncpi04c_truth, test_ncpi04c = train_test_split(ncpi04c, test_size=0.5, random_state=1990)
# Add nu overlay NC pi0 events to NC pi0 training sample
train_ncpi04c = pd.concat([train_ncpi04c_truth, nu4c_ncpi0], ignore_index=True)

# Run 4d
# Query nu overlay sample
nu4d_ccnue = nu4d.query(NUEQUERY)
nu4d_ncpi0 = nu4d.query(NCPI0QUERY)
nu4d_no_ccnue_ncpi0 = nu4d.query('~'+MCQUERY)

# Split remaining nu overlay events
train_nu4d, test_nu4d = train_test_split(nu4d_no_ccnue_ncpi0, test_size=0.5, random_state=1990)

# Query nue overlay sample
nue4d_zp = nue4d.query(ZPQUERY)
nue4d_np = nue4d.query(NPQUERY)
nue4d_other = nue4d.query(NUEOTHERQUERY)

if nue_signal == 'ZP':
    # Make signal and background nue samples
    signal_nue4d = nue4d_zp
    bkg_nue4d = pd.concat([nue4d_np, nue4d_other], ignore_index=True)

if nue_signal == 'ZP_NP':
    # Make signal and background nue samples
    signal_nue4d = pd.concat([nue4d_zp, nue4d_np], ignore_index=True)
    bkg_nue4d = nue4d_other

# Split nue signal and background samples into training and testing samples
train_signal_nue4d, test_signal_nue4d = train_test_split(signal_nue4d, test_size=0.5)
train_bkg_nue4d, test_bkg_nue4d = train_test_split(bkg_nue4d, test_size=0.5)

# Re-unify the signal and background samples
test_nue4d = pd.concat([test_signal_nue4d, test_bkg_nue4d], ignore_index=True)
train_nue4d_truth = pd.concat([train_signal_nue4d, train_bkg_nue4d], ignore_index=True)
# Add nu overlay CC nue events to nue overlay training sample
train_nue4d = pd.concat([train_nue4d_truth, nu4d_ccnue], ignore_index=True)

# Split dirt and NC pi0 as normal
train_dirt4d, test_dirt4d = train_test_split(dirt4d, test_size=0.5, random_state=1990)
train_ncpi04d_truth, test_ncpi04d = train_test_split(ncpi04d, test_size=0.5, random_state=1990)
# Add nu overlay NC pi0 events to NC pi0 training sample
train_ncpi04d = pd.concat([train_ncpi04d_truth, nu4d_ncpi0], ignore_index=True)

# Run 5
# Query nu overlay sample
nu5_ccnue = nu5.query(NUEQUERY)
nu5_ncpi0 = nu5.query(NCPI0QUERY)
nu5_no_ccnue_ncpi0 = nu5.query('~'+MCQUERY)

# Split remaining nu overlay events
train_nu5, test_nu5 = train_test_split(nu5_no_ccnue_ncpi0, test_size=0.5, random_state=1990)

# Query nue overlay sample
nue5_zp = nue5.query(ZPQUERY)
nue5_np = nue5.query(NPQUERY)
nue5_other = nue5.query(NUEOTHERQUERY)

if nue_signal == 'ZP':
    # Make signal and background nue samples
    signal_nue5 = nue5_zp
    bkg_nue5 = pd.concat([nue5_np, nue5_other], ignore_index=True)

if nue_signal == 'ZP_NP':
    # Make signal and background nue samples
    signal_nue5 = pd.concat([nue5_zp, nue5_np], ignore_index=True)
    bkg_nue5 = nue5_other

# Split nue signal and background samples into training and testing samples
train_signal_nue5, test_signal_nue5 = train_test_split(signal_nue5, test_size=0.5)
train_bkg_nue5, test_bkg_nue5 = train_test_split(bkg_nue5, test_size=0.5)

# Re-unify the signal and background samples
test_nue5 = pd.concat([test_signal_nue5, test_bkg_nue5], ignore_index=True)
train_nue5_truth = pd.concat([train_signal_nue5, train_bkg_nue5], ignore_index=True)
# Add nu overlay CC nue events to nue overlay training sample
train_nue5 = pd.concat([train_nue5_truth, nu5_ccnue], ignore_index=True)

# Split dirt and NC pi0 as normal
train_dirt5, test_dirt5 = train_test_split(dirt5, test_size=0.5, random_state=1990)
train_ncpi05_truth, test_ncpi05 = train_test_split(ncpi05, test_size=0.5, random_state=1990)
# Add nu overlay NC pi0 events to NC pi0 training sample
train_ncpi05 = pd.concat([train_ncpi05_truth, nu5_ncpi0], ignore_index=True)

# %%
vars = ["run","subRun"]

ext4a = u_ext4a.arrays(vars, library='pd')
train_ext4a, test_ext4a = train_test_split(ext4a, test_size=0.5, random_state=1990)

ext4b = u_ext4b.arrays(vars, library='pd')
train_ext4b, test_ext4b = train_test_split(ext4b, test_size=0.5, random_state=1990)

ext4c = u_ext4c.arrays(vars, library='pd')
train_ext4c, test_ext4c = train_test_split(ext4c, test_size=0.5, random_state=1990)

ext4d = u_ext4d.arrays(vars, library='pd')
train_ext4d, test_ext4d = train_test_split(ext4d, test_size=0.5, random_state=1990)

ext5 = u_ext5.arrays(vars, library='pd')
train_ext5, test_ext5 = train_test_split(ext5, test_size=0.5, random_state=1990)

# %%
# Run 4a Test POT
test_nu4apot = 0
test_nue4apot = 0
test_dirt4apot = 0
test_ncpi04apot = 0

for i, row in test_nu4a.iterrows():
    test_nu4apot+=row["pot"]

for i, row in test_nue4a.iterrows():
    test_nue4apot+=row["pot"]

for i, row in test_dirt4a.iterrows():
    test_dirt4apot+=row["pot"]

for i, row in test_ncpi04a.iterrows():
    test_ncpi04apot+=row["pot"]

# Run 4b Test POT
test_nu4bpot = 0
test_nue4bpot = 0
test_dirt4bpot = 0
test_ncpi04bpot = 0

for i, row in test_nu4b.iterrows():
    test_nu4bpot+=row["pot"]

for i, row in test_nue4b.iterrows():
    test_nue4bpot+=row["pot"]

for i, row in test_dirt4b.iterrows():
    test_dirt4bpot+=row["pot"]

for i, row in test_ncpi04b.iterrows():
    test_ncpi04bpot+=row["pot"]

# Run 4c Test POT
test_nu4cpot = 0
test_nue4cpot = 0
test_dirt4cpot = 0
test_ncpi04cpot = 0

for i, row in test_nu4c.iterrows():
    test_nu4cpot+=row["pot"]

for i, row in test_nue4c.iterrows():
    test_nue4cpot+=row["pot"]

for i, row in test_dirt4c.iterrows():
    test_dirt4cpot+=row["pot"]

for i, row in test_ncpi04c.iterrows():
    test_ncpi04cpot+=row["pot"]

test_nu4dpot = 0
test_nue4dpot = 0
test_dirt4dpot = 0
test_ncpi04dpot = 0

for i, row in test_nu4d.iterrows():
    test_nu4dpot+=row["pot"]

for i, row in test_nue4d.iterrows():
    test_nue4dpot+=row["pot"]

for i, row in test_dirt4d.iterrows():
    test_dirt4dpot+=row["pot"]

for i, row in test_ncpi04d.iterrows():
    test_ncpi04dpot+=row["pot"]

test_nu5pot = 0
test_nue5pot = 0
test_dirt5pot = 0
test_ncpi05pot = 0

for i, row in test_nu5.iterrows():
    test_nu5pot+=row["pot"]

for i, row in test_nue5.iterrows():
    test_nue5pot+=row["pot"]

for i, row in test_dirt5.iterrows():
    test_dirt5pot+=row["pot"]

for i, row in test_ncpi05.iterrows():
    test_ncpi05pot+=row["pot"]

# %%
print("Run 4a Nu Overlay Test POT = ", test_nu4apot)
print("Run 4a Nue Overlay Test POT = ", test_nue4apot)
print("Run 4a Dirt Overlay Test POT = ", test_dirt4apot)
print("Run 4a NC Pi0 Overlay Test POT = ", test_ncpi04apot)
print()
print("Run 4b Nu Overlay Test POT = ", test_nu4bpot)
print("Run 4b Nue Overlay Test POT = ", test_nue4bpot)
print("Run 4b Dirt Overlay Test POT = ", test_dirt4bpot)
print("Run 4b NC Pi0 Overlay Test POT = ", test_ncpi04bpot)
print()
print("Run 4c Nu Overlay Test POT = ", test_nu4cpot)
print("Run 4c Nue Overlay Test POT = ", test_nue4cpot)
print("Run 4c Dirt Overlay Test POT = ", test_dirt4cpot)
print("Run 4c NC Pi0 Overlay Test POT = ", test_ncpi04cpot)
print()
print("Run 4d Nu Overlay Test POT = ", test_nu4dpot)
print("Run 4d Nue Overlay Test POT = ", test_nue4dpot)
print("Run 4d Dirt Overlay Test POT = ", test_dirt4dpot)
print("Run 4d NC Pi0 Overlay Test POT = ", test_ncpi04dpot)
print()
print("Run 5 Nu Overlay Test POT = ", test_nu5pot)
print("Run 5 Nue Overlay Test POT = ", test_nue5pot)
print("Run 5 Dirt Overlay Test POT = ", test_dirt5pot)
print("Run 5 NC Pi0 Overlay Test POT = ", test_ncpi05pot)
# Out:
# Run 4a Nu Overlay Test POT =  1.1203258623742444e+20
# Run 4a Nue Overlay Test POT =  1.8250689958130546e+22
# Run 4a Dirt Overlay Test POT =  5.408797499974484e+19
# Run 4a NC Pi0 Overlay Test POT =  9.837927197698278e+20
#
# Run 4b Nu Overlay Test POT =  3.7202951889955167e+20
# Run 4b Nue Overlay Test POT =  5.900229779700943e+22
# Run 4b Dirt Overlay Test POT =  1.5309731647852433e+20
# Run 4b NC Pi0 Overlay Test POT =  2.495015022771661e+21
#
# Run 4c Nu Overlay Test POT =  2.2411423343644036e+20
# Run 4c Nue Overlay Test POT =  3.5899611609260274e+22
# Run 4c Dirt Overlay Test POT =  8.982887373345495e+19
# Run 4c NC Pi0 Overlay Test POT =  1.6759563090591262e+21
#
# Run 4d Nu Overlay Test POT =  4.179145119284918e+20
# Run 4d Nue Overlay Test POT =  6.915563774270567e+22
# Run 4d Dirt Overlay Test POT =  1.7251954375645567e+20
# Run 4d NC Pi0 Overlay Test POT =  3.221354362156077e+21
#
# Run 5 Nu Overlay Test POT =  4.77176265660467e+20
# ...

# %%
# test_ext4a.to_csv("test-run4a-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')
# test_ext4b.to_csv("test-run4b-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')
# test_ext4c.to_csv("test-run4c-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')
# test_ext4d.to_csv("test-run4d-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')
# test_ext5.to_csv("test-run5-run-subrun-list-beamOff.txt",header=None, index=None, sep=' ')
